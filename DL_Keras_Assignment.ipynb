# %% [markdown]
# <a href="https://colab.research.google.com/github/BelovedTemitope/U_repo/blob/master/DL_Keras_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import RMSprop, Adam, SGDq
from keras.utils import np_utils
np.random.seed(1671) #for reproducibility

# %%
# network and training
NB_EPOCHs = 200
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10
OPTIMIZER = Adam()
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2

HIDDEN_1 = 300
HIDDEN_2 = 500
HIDDEN_3 = 100
DROPOUT = 0.3

# %%
#data shuffled and split between train and test
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
#X_train has 60000 rows of 28x28 values --> reshaped to 60000x784
RESHAPED = 784

#reshaping X_trian and X_test
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
#normalize
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train_samples')
print(X_test.shape[0], 'test_samples')
#convert class vectors to binary class matrices
y_train = np_utils.to_categorical(y_train, NB_CLASSES)
y_test = np_utils.to_categorical(y_test, NB_CLASSES)
# Out:
# 60000 train_samples
# 10000 test_samples

# %%
#3 HIDDEN hidden layers
#10 outputs .. defining model
#final stage is softmax
model = Sequential()
model.add(Dense(HIDDEN_1, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(HIDDEN_2))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(HIDDEN_3))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 300)               235500
# _________________________________________________________________
# activation_5 (Activation)    (None, 300)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 500)               150500
# _________________________________________________________________
# activation_6 (Activation)    (None, 500)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               50100
# ...

# %%
#compiling the model
model.compile(loss='categorical_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])

# %%
#training the model
history = model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=NB_EPOCHs, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/200
# 48000/48000 [==============================] - 7s 151us/step - loss: 0.3972 - accuracy: 0.8788 - val_loss: 0.1312 - val_accuracy: 0.9598
# Epoch 2/200
# 48000/48000 [==============================] - 7s 148us/step - loss: 0.1640 - accuracy: 0.9513 - val_loss: 0.1101 - val_accuracy: 0.9672
# Epoch 3/200
# 48000/48000 [==============================] - 7s 141us/step - loss: 0.1243 - accuracy: 0.9633 - val_loss: 0.0987 - val_accuracy: 0.9698
# Epoch 4/200
# 48000/48000 [==============================] - 7s 137us/step - loss: 0.1014 - accuracy: 0.9695 - val_loss: 0.0854 - val_accuracy: 0.9746
# Epoch 5/200
# 48000/48000 [==============================] - 7s 137us/step - loss: 0.0861 - accuracy: 0.9738 - val_loss: 0.0936 - val_accuracy: 0.9722
# Epoch 6/200
# 48000/48000 [==============================] - 7s 139us/step - loss: 0.0788 - accuracy: 0.9760 - val_loss: 0.0853 - val_accuracy: 0.9747
# Epoch 7/200
# ...

# %%
score = model.evaluate(X_test, y_test, verbose=VERBOSE)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# 10000/10000 [==============================] - 1s 55us/step
# Test score: 0.11738394192263865
# Test accuracy: 0.9833999872207642
